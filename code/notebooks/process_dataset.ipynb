# %%
import pandas as pd

# %%
df = (
    pd.read_json("../artifacts/data/cleaned/dataset.jsonl", lines=True)
    .set_index(["question_id", "sample_id"])
    .sort_index()
)
df.head()
# Out:
#                                                                 question  \
# question_id sample_id
# 0           0          Natalia sold clips to 48 of her friends in Apr...
#             1          Natalia sold clips to 48 of her friends in Apr...
#             2          Natalia sold clips to 48 of her friends in Apr...
#             5          Natalia sold clips to 48 of her friends in Apr...
#             6          Natalia sold clips to 48 of her friends in Apr...
#
#                                                         gold_answer_text  \
# question_id sample_id
# 0           0          Natalia sold 48/2 = <<48/2=24>>24 clips in May...
#             1          Natalia sold 48/2 = <<48/2=24>>24 clips in May...
#             2          Natalia sold 48/2 = <<48/2=24>>24 clips in May...
#             5          Natalia sold 48/2 = <<48/2=24>>24 clips in May...
#             6          Natalia sold 48/2 = <<48/2=24>>24 clips in May...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 24952 entries, (np.int64(0), np.int64(0)) to (np.int64(999), np.int64(29))
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   question               24952 non-null  object
#  1   gold_answer_text       24952 non-null  object
#  2   gold_answer_number     24952 non-null  int64
#  3   teacher_answer_text    24952 non-null  object
#  4   teacher_answer_number  24952 non-null  int64
#  5   is_correct             24952 non-null  bool
#  6   finish_reason          24952 non-null  object
#  7   usage                  24952 non-null  object
#  8   latency_ms             24952 non-null  int64
#  9   model                  24952 non-null  object
#  10  request_id             24952 non-null  object
# dtypes: bool(1), int64(3), object(7)
# memory usage: 2.0+ MB

# %%
df = df[
    [
        "question",
        "gold_answer_text",
        "gold_answer_number",
        "teacher_answer_text",
        "teacher_answer_number",
    ]
]

# %%
df.reset_index().to_json(
    "../artifacts/data/processed/dataset.jsonl", lines=True, orient="records"
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.reset_index().to_json("../artifacts/data/processed/dataset.jsonl", lines=True, orient="records")
#
# File ~/engineering-thesis/code/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
