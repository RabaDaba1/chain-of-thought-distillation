# %%
import pandas as pd

# %%
df = (
    pd.read_json("../artifacts/data/raw/dataset_test.jsonl", lines=True)
    .set_index(["question_id", "sample_id"])
    .sort_index()
)
df.head()
# Out:
#                                                                 question  \
# question_id sample_id
# 0           0          Janet’s ducks lay 16 eggs per day. She eats th...
# 1           0          A robe takes 2 bolts of blue fiber and half th...
# 2           0          Josh decides to try flipping a house.  He buys...
# 3           0          James decides to run 3 sprints 3 times a week....
# 4           0          Every day, Wendi feeds each of her chickens th...
#
#                                                         gold_answer_text  \
# question_id sample_id
# 0           0          Janet sells 16 - 3 - 4 = <<16-3-4=9>>9 duck eg...
# 1           0          It takes 2/2=<<2/2=1>>1 bolt of white fiber\nS...
# 2           0          The cost of the house and repairs came out to ...
# 3           0          He sprints 3*3=<<3*3=9>>9 times\nSo he runs 9*...
# 4           0          If each chicken eats 3 cups of feed per day, t...
#
# ...

# %%
df["is_correct"].mean()
# Out:
# np.float64(0.9361046959199384)
